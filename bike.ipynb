# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv( "train.csv")
data
# Out:
#         ID        Date     y  Hour  Temperature(�C)  Humidity(%)  \
# 0        0  01/12/2017   254     0             -5.2           37
# 1        1  01/12/2017   204     1             -5.5           38
# 2        2  01/12/2017   173     2             -6.0           39
# 3        3  01/12/2017   107     3             -6.2           40
# 4        4  01/12/2017    78     4             -6.0           36
# ...    ...         ...   ...   ...              ...          ...
# 5755  5755  20/11/2018  1317    19              8.7           34
# 5756  5756  20/11/2018  1078    20              8.5           32
# 5757  5757  20/11/2018  1020    21              8.8           37
# 5758  5758  20/11/2018   922    22              8.9           40
# 5759  5759  20/11/2018   378    23              9.3           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(�C)  \
# 0                  2.2              2000                      -17.6
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5760 entries, 0 to 5759
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         5760 non-null   int64
#  1   Date                       5760 non-null   object
#  2   y                          5760 non-null   int64
#  3   Hour                       5760 non-null   int64
#  4   Temperature(�C)            5760 non-null   float64
#  5   Humidity(%)                5760 non-null   int64
#  6   Wind speed (m/s)           5760 non-null   float64
#  7   Visibility (10m)           5760 non-null   int64
#  8   Dew point temperature(�C)  5760 non-null   float64
#  9   Solar Radiation (MJ/m2)    5760 non-null   float64
#  10  Rainfall(mm)               5760 non-null   float64
#  11  Snowfall (cm)              5760 non-null   float64
#  12  Seasons                    5760 non-null   object
# ...

# %%
data2=pd.read_csv("test.csv")
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         3000 non-null   int64
#  1   Date                       3000 non-null   object
#  2   Hour                       3000 non-null   int64
#  3   Temperature(�C)            3000 non-null   float64
#  4   Humidity(%)                3000 non-null   int64
#  5   Wind speed (m/s)           3000 non-null   float64
#  6   Visibility (10m)           3000 non-null   int64
#  7   Dew point temperature(�C)  3000 non-null   float64
#  8   Solar Radiation (MJ/m2)    3000 non-null   float64
#  9   Rainfall(mm)               3000 non-null   float64
#  10  Snowfall (cm)              3000 non-null   float64
#  11  Seasons                    3000 non-null   object
#  12  Holiday                    3000 non-null   object
# ...

# %%
data.describe().T
# Out:
#                             count         mean          std   min      25%  \
# ID                         5760.0  2879.500000  1662.913107   0.0  1439.75
# y                          5760.0   703.483854   655.249491   0.0   188.00
# Hour                       5760.0    11.500000     6.922788   0.0     5.75
# Temperature(�C)            5760.0    12.803559    11.902206 -15.1     3.20
# Humidity(%)                5760.0    58.361806    19.840167   0.0    43.00
# Wind speed (m/s)           5760.0     1.723333     1.047898   0.0     0.90
# Visibility (10m)           5760.0  1473.711458   585.879880  27.0  1025.75
# Dew point temperature(�C)  5760.0     4.058264    13.003582 -26.9    -5.40
# Solar Radiation (MJ/m2)    5760.0     0.572325     0.869943   0.0     0.00
# Rainfall(mm)               5760.0     0.135122     1.075320   0.0     0.00
# Snowfall (cm)              5760.0     0.046302     0.323728   0.0     0.00
#
#                                50%       75%      max
# ...

# %%
# The count of bikes rented in an hour are 703 to 705 bikes 
data.loc[:,"y"].mean()
# Out:
# 703.4838541666667

# %%
highest_bike_count=data._get_numeric_data().dropna(axis=1)
big=highest_bike_count.loc[data['y']==3556,:]
big
# Out:
#         ID     y  Hour  Temperature(�C)  Humidity(%)  Wind speed (m/s)  \
# 3330  3330  3556    18             24.1           57               2.9
#
#       Visibility (10m)  Dew point temperature(�C)  Solar Radiation (MJ/m2)  \
# 3330              1301                       15.0                     0.56
#
#       Rainfall(mm)  Snowfall (cm)
# 3330           0.0            0.0

# %%
big.describe().T
# Out:
#                            count     mean  std      min      25%      50%  \
# ID                           1.0  3330.00  NaN  3330.00  3330.00  3330.00
# y                            1.0  3556.00  NaN  3556.00  3556.00  3556.00
# Hour                         1.0    18.00  NaN    18.00    18.00    18.00
# Temperature(�C)              1.0    24.10  NaN    24.10    24.10    24.10
# Humidity(%)                  1.0    57.00  NaN    57.00    57.00    57.00
# Wind speed (m/s)             1.0     2.90  NaN     2.90     2.90     2.90
# Visibility (10m)             1.0  1301.00  NaN  1301.00  1301.00  1301.00
# Dew point temperature(�C)    1.0    15.00  NaN    15.00    15.00    15.00
# Solar Radiation (MJ/m2)      1.0     0.56  NaN     0.56     0.56     0.56
# Rainfall(mm)                 1.0     0.00  NaN     0.00     0.00     0.00
# Snowfall (cm)                1.0     0.00  NaN     0.00     0.00     0.00
#
#                                75%      max
# ...

# %%
lowest_bike_count=data._get_numeric_data().dropna(axis=1)
low=lowest_bike_count.loc[data['y']==0,:]
low
# Out:
#         ID  y  Hour  Temperature(�C)  Humidity(%)  Wind speed (m/s)  \
# 2160  2160  0     0             14.4           82               4.6
# 2161  2161  0     1             13.6           81               3.6
# 2162  2162  0     2             12.7           80               3.9
# 2163  2163  0     3             11.6           81               3.1
# 2164  2164  0     4             10.2           83               3.5
# ...    ... ..   ...              ...          ...               ...
# 5491  5491  0    19             11.9           71               2.7
# 5492  5492  0    20             11.9           72               2.5
# 5493  5493  0    21             11.4           74               1.9
# 5494  5494  0    22             11.2           75               1.7
# 5495  5495  0    23             10.9           76               1.2
#
#       Visibility (10m)  Dew point temperature(�C)  Solar Radiation (MJ/m2)  \
# ...

# %%
low.describe().T
# Out:
#                            count         mean          std     min      25%  \
# ID                         247.0  4537.153846  1086.925930  2160.0  4741.50
# y                          247.0     0.000000     0.000000     0.0     0.00
# Hour                       247.0    11.259109     6.989951     0.0     5.00
# Temperature(�C)            247.0    15.776518     4.966131     5.2    11.80
# Humidity(%)                247.0    61.457490    16.734573    21.0    49.00
# Wind speed (m/s)           247.0     1.704049     1.100140     0.0     0.90
# Visibility (10m)           247.0  1435.599190   595.276841   201.0   920.00
# Dew point temperature(�C)  247.0     7.683401     4.531857    -7.0     5.25
# Solar Radiation (MJ/m2)    247.0     0.618219     0.907081     0.0     0.00
# Rainfall(mm)               247.0     0.162753     1.314363     0.0     0.00
# Snowfall (cm)              247.0     0.000000     0.000000     0.0     0.00
#
#                               50%       75%      max
# ...

# %%
data['Functioning Day'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
sns.color_palette("hls",8)
sns.set(style='whitegrid',palette='deep')
sns.countplot(data['Functioning Day'],palette="pastel");

# %%
# there is a high correlation between the bike count and temperature
correlate=data.corr()['y']
correlate
# Out:
# ID                           0.365359
# y                            1.000000
# Hour                         0.407180
# Temperature(�C)              0.544281
# Humidity(%)                 -0.191603
# Wind speed (m/s)             0.116380
# Visibility (10m)             0.214777
# Dew point temperature(�C)    0.392454
# Solar Radiation (MJ/m2)      0.250601
# Rainfall(mm)                -0.117711
# Snowfall (cm)               -0.120836
# Name: y, dtype: float64

# %%
plt.figure(figsize=(16,12))
matrix=data.corr(method='pearson')
#customized diverging palette
cmap=sns.diverging_palette(250,15,s=75,l=40,center="light",as_cmap=True)
_=sns.heatmap(matrix,center=0,annot=True,fmt='.2f',square=True,cmap=cmap)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\textpath.py:90: RuntimeWarning: Glyph 65533 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\textpath.py:203: RuntimeWarning: Glyph 65533 missing from current font.
#   glyph = font.load_char(ccode, flags=LOAD_NO_HINTING)

# %%
plt.figure(figsize=(16,12))
matrix=data.corr(method='pearson')
#customized diverging palette
mask=np.triu(np.ones_like(matrix,dtype=bool))
cmap=sns.diverging_palette(250,15,s=75,l=40,center="light",as_cmap=True)
_=sns.heatmap(matrix,mask=mask,center=0,annot=True,fmt='.2f',square=True,cmap=cmap)

# %%
class Data_plots:
    """
    my method of data related plots

    pairplot:creates plots pairwise relation between all features and output
    plot_fitted:plots fitted values against the true output values from the data
    """
    def pairplot(self):
        '''creates pairplot of all variables and the target using the seaborn library'''
        print("take a coffee break this might take a while... ")
        from seaborn import pairplot
        from pandas import DataFrame
        data=DataFrame(np.hstack((self.features_,self.target_.reshape(-1,1))))
        pairplot(data)
